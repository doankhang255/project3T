# %%
import os
import requests
import pandas as pd

your_key = os.getenv("X_API_KEY")
url = "https://gateway.datacore.vn/data/ds/search"

headers = {
    "x-api-key": "",
    "Content-Type": "application/json"
}

payload = {
    "dataSetCode": "dataset_historical_price", #name of datasetCode
    "conditions": [],
    "selectFields": [],
    "page": 1, 
    "limit": 100 # 719603
}
res = requests.post(url, headers=headers, json=payload)
# print(res)
data = res.json()
# print(data)
# Out:
# page 1: 0 records
# No more records. Stop.
# No data to save.
