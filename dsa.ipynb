# %%
import pandas as pd
df = pd.read_csv('data_Histo/vnindex_eda_output.csv')
df.columns
# Out:
# Index(['symbol', 'date', 'high_price', 'low_price', 'open_price',
#        'average_price', 'close_price', 'basic_price', 'adj_ratio', 'unit',
#        'vol_total', 'vol_deal', 'vol_putth', 'val_total', 'val_putth',
#        'buy_vol_foreign', 'buy_val_foreigh', 'sell_vol_foreign',
#        'sel_val_foreign', 'buy_count', 'buy_vol', 'sell_count', 'sell_vol',
#        'foreign_room', 'prop_trading_deal', 'prop_trading_putth',
#        'prop_trading_net', 'year'],
#       dtype='object')

# %%
df.head()
# Out:
#     symbol        date  high_price  low_price  open_price  average_price  \
# 0  VNINDEX  2010-01-04      517.05     501.74      501.74         517.05
# 1  VNINDEX  2010-01-05      539.39     529.23      529.23         532.53
# 2  VNINDEX  2010-01-06      538.84     526.37      529.47         534.46
# 3  VNINDEX  2010-01-07      540.77     530.68      536.78         533.34
# 4  VNINDEX  2010-01-08      544.49     520.90      540.95         520.90
#
#    close_price  basic_price  adj_ratio  unit  ...  sel_val_foreign  buy_count  \
# 0       517.05       494.77        1.0   1.0  ...     1.863560e+11    35017.0
# 1       532.53       517.05        1.0   1.0  ...     2.835830e+11    38919.0
# 2       534.46       532.53        1.0   1.0  ...     1.578620e+11    44534.0
# 3       533.34       534.46        1.0   1.0  ...     1.495040e+11    48977.0
# 4       520.90       533.34        1.0   1.0  ...     1.995820e+11    47171.0
#
# ...

# %%
len(df)
# Out:
# 3826

# %%
import pandas as pd
df = pd.read_parquet('data_News/equity_news_clean_content.parquet')
df.columns
# Out:
# Index(['link', 'publication_date', 'domain_norm', 'category', 'title',
#        'description', 'keywords_norm', 'content'],
#       dtype='object')

# %%
len(df)
# Out:
# 126576
